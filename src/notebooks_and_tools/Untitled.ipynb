# %%
import os
import pandas as pd

# %%
file = r'C:\Users\rb01243\OneDrive - University of Surrey\Documents\GitHub\C-YOLOv3\v3-crowd\data\datasets\Zoon_50min_2perImg_ProcessedData.csv'

csvDF = pd.read_csv(file)
print(csvDF.head())
print('Number of total bounding boxes: ', len(csvDF))
print('Number of classes: ')
print(csvDF['class'].value_counts())
print('User Counts: ')
print(csvDF['user'].value_counts())
print('Number of volunteers: ', csvDF['user'].nunique())
print('Number of total images: ', csvDF['image'].nunique())
# Out:
#                                    image           user         x         y  \
# 0  0000001-X-20061214-141834-X0000001C-3  chrispsimmons  0.521844  0.211343
# 1  0000001-X-20061214-141834-X0000001C-3  chrispsimmons  0.271981  0.209766
# 2  0000001-X-20061214-141834-X0000001C-3  chrispsimmons  0.534951  0.365346
# 3  0000001-X-20061214-141834-X0000001C-3  chrispsimmons  0.482931  0.384268
# 4  0000001-X-20061214-141834-X0000001C-3  chrispsimmons  0.608272  0.305427
#
#           w         h  class  volInImg
# 0  0.091753  0.045202      1         4
# 1  0.054069  0.035741      1         4
# 2  0.031130  0.025229      1         4
# 3  0.053249  0.033639      1         4
# 4  0.053249  0.035741      1         4
# Number of total bounding boxes:  20033
# Number of classes:
# 0    12777
# 1     7256
# Name: class, dtype: int64
# User Counts:
# chrispsimmons                         3362
# andrven                               1949
# ruirasjudith                          1492
# ...
